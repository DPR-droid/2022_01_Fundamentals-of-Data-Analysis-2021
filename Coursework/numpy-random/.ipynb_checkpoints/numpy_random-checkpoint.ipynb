# %% [markdown]
# # The Numpy Random Package
#
# [Official Documentation](https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
# Efficient numerical arrays.
import numpy as np
# Plotting.
import matplotlib.pyplot as plt

# %%
# Change default style sheet.
#plt.style.use('ggplot')
plt.style.use('fivethirtyeight')
# Change the default figure size
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# # numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at the first ten items.
s[:10]
# Out:
# array([-0.03194777,  0.11047435,  0.02691335,  0.08120204,  0.02210079,
#        -0.12570178,  0.01256373,  0.056458  ,  0.20945865,  0.03583469])

# %%
abs(mu - np.mean(s))
# Out:
# 0.0018273100383735996

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0016625913959604777

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2)

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma*np.sqrt(2 * np.pi))*np.exp(-(bins - mu)**2/(2 * sigma**2))
plt.plot(bins,f,linewidth=2)

# %% [markdown]
# # References
#
# 1. https://realpython.com/python-random/
# 2. https://www.datacamp.com/community/tutorials/numpy-random

# %% [markdown]
# ***
#
# # End
